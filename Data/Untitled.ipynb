# %%
import pandas as pd

# %%
df=pd.read_excel('2020.Newspaper_Workers_Union_survey.xlsx')
df
# Out:
#             Unnamed: 0  Reporter  Manager        Gerne    Region
# 0             Hokkaido     21.54     2.48        Local  Hokkaido
# 1         Dairy Tohoku     29.76     8.33        Local    Tohoku
# 2             Toonippo     20.66     0.00        Local    Tohoku
# 3        Akitasakigake     27.18     5.97        Local    Tohoku
# 4               Iwate      30.86     1.89        Local    Tohoku
# 5               Kahoku     21.02     6.67        Local    Tohoku
# 6                Chiba     14.81     0.00        Local     Kanto
# 7              Ibaraki     22.08     8.70        Local     Kanto
# 8              Shimono     30.58     4.65        Local     Kanto
# 9                Jyomo     26.47     6.00        Local     Kanto
# 10               Asahi     21.90     9.71     National         —
# 11            Mainichi     23.57    10.00     National         —
# 12           Yomiuri.E     19.70    10.92     National         —
# ...

# %%
df.groupby(by='Gerne').Manager.mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='Gerne'>

# %%
df.groupby(by='Gerne').Manager.mean().round(2)
# Out:
# Gerne
# Block          5.64
# Local          6.08
# National       8.70
# Specialized    4.14
# Name: Manager, dtype: float64

# %%
df.groupby(by='Gerne').Reporter.mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='Gerne'>

# %%
df.groupby(by='Gerne').Reporter.mean().round(2)
# Out:
# Gerne
# Block          17.34
# Local          23.03
# National       22.06
# Specialized     8.34
# Name: Reporter, dtype: float64
